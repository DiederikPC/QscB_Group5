# %%
import stochpy

smod = stochpy.SSA()
smod.DoStochSim(IsTrackPropensities=True)
smod.PlotAverageSpeciesTimeSeries
# Out:
# <bound method PlottingFunctions.PlotAverageSpeciesTimeSeries of <stochpy.modules.StochSim.SSA object at 0x106504790>>
